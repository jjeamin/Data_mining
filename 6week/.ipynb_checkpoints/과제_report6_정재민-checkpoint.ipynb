# %% [markdown]
# ## 실습 #5의 iris 데이터로부터 추출된  결과를 이용하여 아래문제를 해결하세요.
#
#
# ## 실습 #5 : iris 데이터를 종별로 분리하여 20개씩 샘플링한 결과를 결합
#
#
# - 1)3개 종에 대한 boxplot  (subplot 이용)
# - 2)3개 종에 대한 histogram
# - 3)3개 종에 대한 scatter plot을 결합
#    + 3-1)Sepal width, Petal width 이용
#    + 3-2)Sepal length, Petal length 이용
# - 4) 결합된 데이터의 scatter matrix
# - 5) 결합된 데이터의 평균에 대한 bar, pie plot

# %% [markdown]
# # 실습5 에서 출력된 결과

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

#iris = load_iris()

# target을 붙이고 species columns 추가
# df = pd.DataFrame(data = np.c_[iris.data,iris.target], columns = iris.feature_names + ['Species'])
# target에 이름 지정해주기
# df['Species'] = df['Species'].map({0: "setosa",1: "versicolor",2: "virginica"})

df = pd.read_csv('irisData.csv')

grouped = df.groupby('Species')

setosa = grouped.get_group(name='setosa')
versicolor = grouped.get_group(name='versicolor')
virginica = grouped.get_group(name='virginica')

setosa20 = setosa.sample(20)
versic20 = versicolor.sample(20)
virgin20 = virginica.sample(20)

iris20 = setosa20.append(versic20)
iris20 = iris20.append(virgin20)

display(iris20)
# Out:
#      Sepal length  Sepal width  Petal length  Petal width     Species
# 20            5.4          3.4           1.7          0.2      setosa
# 24            4.8          3.4           1.9          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 42            4.4          3.2           1.3          0.2      setosa
# 25            5.0          3.0           1.6          0.2      setosa
# 31            5.4          3.4           1.5          0.4      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 41            4.5          2.3           1.3          0.3      setosa
# 32            5.2          4.1           1.5          0.1      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 23            5.1          3.3           1.7          0.5      setosa
# 40            5.0          3.5           1.3          0.3      setosa
# 39            5.1          3.4           1.5          0.2      setosa
# 27            5.2          3.5           1.5          0.2      setosa
# 29            4.7          3.2           1.6          0.2      setosa
# 49            5.0          3.3           1.4          0.2      setosa
# 12            4.8          3.0           1.4          0.1      setosa
# 73            6.1          2.8           4.7          1.2  versicolor
# 67            5.8          2.7           4.1          1.0  versicolor
# 89            5.5          2.5           4.0          1.3  versicolor
# 60            5.0          2.0           3.5          1.0  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 92            5.8          2.6           4.0          1.2  versicolor
# 93            5.0          2.3           3.3          1.0  versicolor
# 80            5.5          2.4           3.8          1.1  versicolor
# 90            5.5          2.6           4.4          1.2  versicolor
# 81            5.5          2.4           3.7          1.0  versicolor
# 84            5.4          3.0           4.5          1.5  versicolor
# 74            6.4          2.9           4.3          1.3  versicolor
# 83            6.0          2.7           5.1          1.6  versicolor
# 85            6.0          3.4           4.5          1.6  versicolor
# 97            6.2          2.9           4.3          1.3  versicolor
# 66            5.6          3.0           4.5          1.5  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 65            6.7          3.1           4.4          1.4  versicolor
# 79            5.7          2.6           3.5          1.0  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 134           6.1          2.6           5.6          1.4   virginica
# 120           6.9          3.2           5.7          2.3   virginica
# 144           6.7          3.3           5.7          2.5   virginica
# 104           6.5          3.0           5.8          2.2   virginica
# 135           7.7          3.0           6.1          2.3   virginica
# 108           6.7          2.5           5.8          1.8   virginica
# 125           7.2          3.2           6.0          1.8   virginica
# 128           6.4          2.8           5.6          2.1   virginica
# 136           6.3          3.4           5.6          2.4   virginica
# 149           5.9          3.0           5.1          1.8   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 126           6.2          2.8           4.8          1.8   virginica
# 100           6.3          3.3           6.0          2.5   virginica
# 139           6.9          3.1           5.4          2.1   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 137           6.4          3.1           5.5          1.8   virginica
# 132           6.4          2.8           5.6          2.2   virginica
# 127           6.1          3.0           4.9          1.8   virginica
# 119           6.0          2.2           5.0          1.5   virginica
# 141           6.9          3.1           5.1          2.3   virginica

# %% [markdown]
# ##  1)3개 종에 대한 boxplot  (subplot 이용)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setosa

# %%
iris20_grouped = iris20.groupby('Species')

setosa20_group = iris20_grouped.get_group(name='setosa')

setosa20_group.plot.bar(rot=0, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B19A828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B376630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B38D908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B3A4D68>],
#       dtype=object)

# %% [markdown]
# ### versicolor

# %%
versicolor20_group = iris20_grouped.get_group(name='versicolor')

versicolor20_group.plot.bar(rot=0,subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B4E66A0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B14EC50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B099C6AC18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B099C1C278>],
#       dtype=object)

# %% [markdown]
# ### virginica

# %%
virginica20_group = iris20_grouped.get_group(name='virginica')

virginica20_group.plot.bar(rot=0, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09AED06D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09AE97668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09AF39748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002B099D3D240>],
#       dtype=object)

# %% [markdown]
# ## 2)3개 종에 대한 histogram

# %%
def setting(name,x,y):
    plt.title(name)
    plt.xlabel(x)
    plt.ylabel(y)
# 이름을 셋팅해주는 함수

# %% [markdown]
# ### Setosa

# %%
setosa20_group.plot.hist()
setting("setosa histogram","DATA","CM")

setosa20_group.plot.hist(bins=3)
setting("setosa histogram","DATA","CM")

setosa20_group.hist()

setosa20_group.hist(bins=3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B650C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B667F28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B6844E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B69BA58>]],
#       dtype=object)

# %% [markdown]
# ### versicolor

# %%
versicolor20_group.plot.hist()
setting("versicolor histogram","DATA","CM")

versicolor20_group.plot.hist(bins=3)
setting("versicolor histogram","DATA","CM")

versicolor20_group.hist()

versicolor20_group.hist(bins=3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09AF5A5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B56B940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B580EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09B611470>]],
#       dtype=object)

# %% [markdown]
# ### virginca

# %%
virginica20_group.plot.hist()
setting("virginica histogram","DATA","CM")

virginica20_group.plot.hist(bins=3)
setting("virginica histogram","DATA","CM")

virginica20_group.hist()

virginica20_group.hist(bins=3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C989908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C9A2C18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C9BE1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C9D6748>]],
#       dtype=object)

# %% [markdown]
# ## 3개 종에 대한 scatter plot을 결합
#
# ### 3-1 sepal length ,petal length 사용

# %%
ax = setosa20_group.plot.scatter(x='Sepal length', y='Petal length', c='Red',label='setosa')
ax = versicolor20_group.plot.scatter(x='Sepal length', y='Petal length', c='Green',label='versicolor',ax=ax)
ax = virginica20_group.plot.scatter(x='Sepal length', y='Petal length', c='Blue',label='virginica',ax=ax)

# %% [markdown]
# ### 3-2 sepal width ,petal width 사용

# %%
ax = setosa20_group.plot.scatter(x='Sepal width', y='Petal width', c='Red',label='setosa')
ax = versicolor20_group.plot.scatter(x='Sepal width', y='Petal width', c='Green',label='versicolor',ax=ax)
ax = virginica20_group.plot.scatter(x='Sepal width', y='Petal width', c='Blue',label='virginica',ax=ax)

# %% [markdown]
# ## 결합된 데이터의 scatter matrix

# %%
import mglearn
iris_class = iris20['Species'].map({"setosa": 0,"versicolor": 1,"virginica": 2})

# kde
pd.plotting.scatter_matrix(iris20,s=60,figsize=(15, 15),marker='o',c=iris_class,
                           diagonal='kde',cmap = mglearn.cm3)

# histogram
pd.plotting.scatter_matrix(iris20,s=60,figsize=(15, 15),marker='o',c=iris_class,
                           diagonal='hist',cmap = mglearn.cm3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09CAC0AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C962780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C966CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C8472B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C8E4828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C8DADA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C8A4208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C888780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C8ADCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C9212B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09C8F0828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09CB78DA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B09CB8E358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09CB9E8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09CBB1E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B09CBC6400>]],
#       dtype=object)

# %% [markdown]
# ## 결합된 데이터의 평균에 대한 bar

# %%
# 결합된 데이터
iris_mean = iris20.mean()

iris_mean.plot.bar(rot=0)

# %%
# 품종별로
iris_class = iris20.groupby(iris20['Species']).mean()
iris_class.columns.name = 'feature'

iris_class.plot.bar(rot=0)

# %% [markdown]
# ## 결합된 데이터의 평균에 대한 pie plot

# %%
iris_mean.plot.pie(title = "iris20 mean")

# %%
iris_class.plot.pie(title = "Sepal length mean",y="Sepal length")
iris_class.plot.pie(title = "Sepal width mean",y="Sepal width")
iris_class.plot.pie(title = "Petal length mean",y="Petal length")
iris_class.plot.pie(title = "Petal width mean",y="Petal width")
